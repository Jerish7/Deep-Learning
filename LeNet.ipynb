# %%
#Importing required libraries
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
from tensorflow.keras.models import Sequential

# %%
#Loading the dataset
(x_train, y_train), (x_test, y_test)=mnist.load_data()

# %%
#Performing reshaping
x_train=x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test=x_test.reshape(x_test.shape[0], 28, 28, 1)

#Normalization
x_train=x_train/255
x_test=x_test/255

# %%
#One hot encoding
y_train=tf.keras.utils.to_categorical(y_train, 10)
y_test=tf.keras.utils.to_categorical(y_test, 10)

# %%
#Building the model
model=Sequential()

#First convolution layer
model.add(Conv2D(6, kernel_size=(5, 5), activation='relu', input_shape=(28, 28, 1)))

#First maxpooling layer
model.add(MaxPooling2D(pool_size=(2, 2)))

#Second convolution layer
model.add(Conv2D(16, kernel_size=(5, 5), activation='relu'))

#Second maxpooling layer
model.add(MaxPooling2D(pool_size=(2, 2)))

#Flatten the model
model.add(Flatten())

#Dense layer
model.add(Dense(120, activation='relu'))
model.add(Dense(84, activation='relu'))

#Output layer
model.add(Dense(10, activation='softmax'))

# %%
#Compile the model
model.compile(loss=tf.keras.metrics.categorical_crossentropy, optimizer=tf.keras.optimizers.Adam(),metrics=['accuracy'])

#Fit the model
model.fit(x_train, y_train, batch_size=128, epochs=20, verbose=1, validation_data=(x_test, y_test))

#Verbose shows the progress of the training epochs
# 0 = silent, 1 = progress bar, 2 = one line per epoch
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 31s 514us/sample - loss: 0.3301 - accuracy: 0.8999 - val_loss: 0.1214 - val_accuracy: 0.9618
# Epoch 2/20
# 60000/60000 [==============================] - 25s 422us/sample - loss: 0.0947 - accuracy: 0.9712 - val_loss: 0.0638 - val_accuracy: 0.9799
# Epoch 3/20
# 60000/60000 [==============================] - 23s 383us/sample - loss: 0.0682 - accuracy: 0.9789 - val_loss: 0.0618 - val_accuracy: 0.9787
# Epoch 4/20
# 60000/60000 [==============================] - 23s 380us/sample - loss: 0.0528 - accuracy: 0.9828 - val_loss: 0.0409 - val_accuracy: 0.9866
# Epoch 5/20
# 60000/60000 [==============================] - 21s 354us/sample - loss: 0.0443 - accuracy: 0.9863 - val_loss: 0.0400 - val_accuracy: 0.9869
# Epoch 6/20
# 60000/60000 [==============================] - 23s 386us/sample - loss: 0.0365 - accuracy: 0.9884 - val_loss: 0.0471 - val_accuracy: 0.9842
# Epoch 7/20
# 60000/60000 [==============================] - 27s 452us/sample - loss: 0.0326 - accuracy: 0.9895 - val_loss: 0.0444 - val_accuracy: 0.9858
# Epoch 8/20
# 60000/60000 [==============================] - 26s 430us/sample - loss: 0.0294 - accuracy: 0.9904 - val_loss: 0.0380 - val_accuracy: 0.9867
# Epoch 9/20
# 60000/60000 [==============================] - 25s 422us/sample - loss: 0.0247 - accuracy: 0.9916 - val_loss: 0.0327 - val_accuracy: 0.9892
# Epoch 10/20
# 60000/60000 [==============================] - 24s 408us/sample - loss: 0.0231 - accuracy: 0.9923 - val_loss: 0.0342 - val_accuracy: 0.9886
# Epoch 11/20
# 60000/60000 [==============================] - 26s 434us/sample - loss: 0.0192 - accuracy: 0.9936 - val_loss: 0.0335 - val_accuracy: 0.9894
# Epoch 12/20
# 60000/60000 [==============================] - 27s 450us/sample - loss: 0.0176 - accuracy: 0.9940 - val_loss: 0.0356 - val_accuracy: 0.9889
# Epoch 13/20
# 60000/60000 [==============================] - 24s 401us/sample - loss: 0.0158 - accuracy: 0.9948 - val_loss: 0.0362 - val_accuracy: 0.9896
# Epoch 14/20
# 60000/60000 [==============================] - 25s 410us/sample - loss: 0.0148 - accuracy: 0.9948 - val_loss: 0.0373 - val_accuracy: 0.9890
# Epoch 15/20
# 60000/60000 [==============================] - 25s 420us/sample - loss: 0.0140 - accuracy: 0.9952 - val_loss: 0.0390 - val_accuracy: 0.9893
# Epoch 16/20
# 60000/60000 [==============================] - 26s 426us/sample - loss: 0.0125 - accuracy: 0.9954 - val_loss: 0.0416 - val_accuracy: 0.9887
# Epoch 17/20
# 60000/60000 [==============================] - 25s 414us/sample - loss: 0.0126 - accuracy: 0.9954 - val_loss: 0.0411 - val_accuracy: 0.9893
# Epoch 18/20
# 60000/60000 [==============================] - 23s 386us/sample - loss: 0.0090 - accuracy: 0.9971 - val_loss: 0.0390 - val_accuracy: 0.9893
# Epoch 19/20
# 60000/60000 [==============================] - 24s 398us/sample - loss: 0.0102 - accuracy: 0.9964 - val_loss: 0.0446 - val_accuracy: 0.9896
# Epoch 20/20
# 60000/60000 [==============================] - 24s 406us/sample - loss: 0.0091 - accuracy: 0.9968 - val_loss: 0.0362 - val_accuracy: 0.9908

# %%
#Using test data
score=model.evaluate(x_test, y_test)
print('Test loss: ',score[0])
print('Test accuracy: ',score[1])
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Test loss:  0.03624495150630828
# Test accuracy:  0.9908
